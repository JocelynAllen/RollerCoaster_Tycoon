# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
csv_path = "rollercoasters.csv"
rollercoaster_df = pd.read_csv(csv_path)
rollercoaster_df.tail()
# Out:
#      park_id            theme      rollercoaster_type  custom_design  \
# 137       30  Botany Breakers          Spiral Coaster              1
# 138       30  Botany Breakers         Twister Coaster              1
# 139       30  Botany Breakers      Mine Train Coaster              1
# 140       30  Botany Breakers  Wooden Roller Coaster               1
# 141       30  Botany Breakers            Hypercoaster              1
#
#      excitement excitement_rating  intensity intensity_rating  nausea  \
# 137        5.39              High       5.94             High    3.79
# 138        7.66              High       6.11             High    3.81
# 139        7.59              High       7.60             High    5.80
# 140        7.50              High       7.75        Very High    4.35
# 141        6.17              High      44.94           Medium    2.76
#
#     nausea_rating     ...      avg_speed  ride_time  ride_length  max_pos_gs  \
# ...

# %%
corrMatrix = rollercoaster_df.corr()
print (corrMatrix)
# Out:
#                       park_id  excitement  intensity    nausea  max_speed  \
# park_id              1.000000    0.208506   0.170565  0.122935   0.286958
# excitement           0.208506    1.000000   0.218619  0.349712   0.500800
# intensity            0.170565    0.218619   1.000000  0.195823   0.191066
# nausea               0.122935    0.349712   0.195823  1.000000   0.193787
# max_speed            0.286958    0.500800   0.191066  0.193787   1.000000
# avg_speed            0.199232    0.393300   0.149153  0.207210   0.659485
# ride_time            0.112578    0.310817  -0.006945  0.122904   0.189501
# ride_length          0.196867    0.555398   0.094163  0.204650   0.503572
# max_pos_gs           0.235944    0.296372   0.150158  0.199447   0.631194
# max_neg_gs          -0.086916    0.004703   0.009947 -0.018263  -0.095027
# max_lateral_gs      -0.019231    0.147490   0.236579  0.268021   0.099968
# total_air_time       0.001091    0.513925   0.060871  0.164505   0.533315
# ...

# %%
import seaborn as sn
plt.figure(figsize = (16,5))
sn.heatmap(corrMatrix, annot=True)
fig = plt.show()
#highest drop height and avg speed .55
#ride length and excitement .56
#avg speed and max speed .66
#max psos gs and max sped .63 
#highest drop and max speed .93
#ride length and ride time .83

# %%
rollercoaster_df.describe()
# Out:
#           park_id  custom_design  excitement   intensity     nausea  \
# count  142.000000     142.000000  142.000000  142.000000  142.00000
# mean    16.985915       0.697183    6.337183    6.798028    4.35493
# std      8.727543       0.461103    1.228618    3.516611    1.40691
# min      0.000000       0.000000    2.460000    1.930000    1.33000
# 25%     10.000000       0.000000    5.720000    5.552500    3.39500
# 50%     19.000000       1.000000    6.405000    6.585000    4.25500
# 75%     24.000000       1.000000    7.035000    7.627500    5.11000
# max     30.000000       1.000000    9.480000   44.940000    9.85000
#
#         max_speed   avg_speed   ride_time  ride_length  max_pos_gs  \
# count  142.000000  142.000000  142.000000   142.000000  142.000000
# mean    43.570423   14.063380   71.957746  1987.528169    3.235141
# std      8.980197    4.817543   21.639822   826.862726    0.715725
# min     29.000000    1.000000   12.000000   620.000000    2.140000
# ...

# %%
lat_temp = plt.scatter(rollercoaster_df['excitement'], rollercoaster_df['intensity'], marker="o", facecolors="gold", edgecolors="black",
             alpha=0.75)

# # Incorporate the other graph properties

plt.xlabel("excitement")
plt.ylabel("intensity")

# # Incorporate a text label regarding circle size
plt.title("Excitement v Intensity")
# # Save Figure
plt.show()

#Botany Breakers is the outlier

# %%
import seaborn as sns
sns.lmplot( x="excitement", y="intensity", data=rollercoaster_df, fit_reg=False, hue='custom_design', legend=False)
 
# Move the legend to an empty part of the plot
plt.legend(loc='upper right')
plt.title("Excitement v Intensity")
#Botany Breakers is the outlier

# %%
groupby_sum1 = rollercoaster_df['excitement'].sum() 
print(groupby_sum1)
# Out:
# 899.88

# %%
#0 is false. 1 is true
rollercoaster_df['custom_design'] = rollercoaster_df['custom_design'].replace(0, 'False')
rollercoaster_df['custom_design'] = rollercoaster_df['custom_design'].replace(1, 'True')

# %%
preloaded = rollercoaster_df[rollercoaster_df.custom_design == 'False']
designed = rollercoaster_df[rollercoaster_df.custom_design == 'True']

# %%
preloaded.head()
# Out:
#    park_id             theme      rollercoaster_type custom_design  \
# 0        0     Barony Bridge      Bobsleigh Coaster          False
# 1        0     Barony Bridge            Dinghy Slide         False
# 2        0     Barony Bridge              Wild Mouse         False
# 3        0     Barony Bridge  Wooden Roller Coaster          False
# 4        1  Forest Frontiers   Junior Roller Coaster         False
#
#    excitement excitement_rating  intensity intensity_rating  nausea  \
# 0        5.49              High       5.71             High    4.86
# 1        4.83            Medium       5.86             High    3.50
# 2        7.64              High       7.86        Very High    4.87
# 3        7.69              High       7.92        Very High    4.75
# 4        5.17              High       5.54             High    3.81
#
#   nausea_rating     ...      avg_speed  ride_time  ride_length  max_pos_gs  \
# ...

# %%
designed.head()
# Out:
#     park_id             theme        rollercoaster_type custom_design  \
# 8         3   Mystic Mountain   Stand Up Roller Coaster          True
# 9         3   Mystic Mountain    Wooden Roller Coaster           True
# 10        4  Pacific Pyramids  Compact Inverted Coaster          True
# 11        4  Pacific Pyramids    Looping Roller Coaster          True
# 12        4  Pacific Pyramids   Stand Up Roller Coaster          True
#
#     excitement excitement_rating  intensity intensity_rating  nausea  \
# 8         5.36              High       8.66        Very High    5.97
# 9         6.33              High       7.24             High    4.56
# 10        6.05              High       7.64             High    6.37
# 11        5.76              High       5.44             High    2.49
# 12        2.72            Medium       5.29             High    4.25
#
#    nausea_rating     ...      avg_speed  ride_time  ride_length  max_pos_gs  \
# ...

# %%
groupby_sum1 = preloaded['excitement'].sum() 
print(groupby_sum1)
# Out:
# 296.62

# %%
groupby_sum2 = designed['excitement'].sum() 
print(groupby_sum2)
# Out:
# 603.26

# %%
import seaborn as sns
sns.boxplot( x=rollercoaster_df["custom_design"], y=rollercoaster_df["intensity"] )

# %%
groupby_sum2 - groupby_sum1
# Out:
# 306.64
